# %%
import graphviz
import numpy as np
import scipy
import sklearn
import shap
import pandas as pd

# %%
df = pd.read_csv('../../common/assets/dataset.csv')
df
# Out:
#     checking_status  duration                  credit_history  \
# 0                <0       6.0  critical/other existing credit
# 1          0<=X<200      48.0                   existing paid
# 2       no checking      12.0  critical/other existing credit
# 3                <0      42.0                   existing paid
# 4                <0      24.0              delayed previously
# ..              ...       ...                             ...
# 995     no checking      12.0                   existing paid
# 996              <0      30.0                   existing paid
# 997     no checking      12.0                   existing paid
# 998              <0      45.0                   existing paid
# 999        0<=X<200      45.0  critical/other existing credit
#
#                  purpose  credit_amount    savings_status  employment  \
# 0               radio/tv         1169.0  no known savings         >=7
# 1               radio/tv         5951.0              <100      1<=X<4
# ...

# %%
from  sklearn.metrics import accuracy_score
orig_model = sklearn.tree.DecisionTreeClassifier(max_depth=50)

orig_model.fit(df.drop(columns=['class','checking_status', 'credit_history']), df['class'])
accuracy_score(orig_model.predict(df.drop(columns=['class']), df['class']))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_15820/1411891535.py in ?()
#       1 from  sklearn.metrics import accuracy_score
#       2 orig_model = sklearn.tree.DecisionTreeClassifier(max_depth=50)
#       3
# ----> 4 orig_model.fit(df.drop(columns=['class','checking_status', 'credit_history']), df['class'])
#       5 accuracy_score(orig_model.predict(df.drop(columns=['class']), df['class']))
#
# ~/projects/python_projects/MIIGAIK-SummerPractice-DataScience/.venv/lib64/python3.10/site-packages/sklearn/base.py in ?(estimator, *args, **kwargs)
#    1359                 skip_parameter_validation=(
#    1360                     prefer_skip_nested_validation or global_skip_validation
#    1361                 )
#    1362             ):
# -> 1363                 return fit_method(estimator, *args, **kwargs)
#
# ...
